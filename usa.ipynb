# %%
import numpy as np
import pandas as pd

# %%
usa = pd.read_html("https://developers.google.com/public-data/docs/canonical/states_csv")
usa_cord = pd.DataFrame(usa[0])

# %%
usa_cord.head()
# Out:
#   state   latitude   longitude        name
# 0    AK  63.588753 -154.493062      Alaska
# 1    AL  32.318231  -86.902298     Alabama
# 2    AR  35.201050  -91.831833    Arkansas
# 3    AZ  34.048928 -111.093731     Arizona
# 4    CA  36.778261 -119.417932  California

# %%
del usa_cord['state']

# %%
usa_cord.columns = ['latitude', 'longitude', 'state']
usa_cord.head()
# Out:
#     latitude   longitude       state
# 0  63.588753 -154.493062      Alaska
# 1  32.318231  -86.902298     Alabama
# 2  35.201050  -91.831833    Arkansas
# 3  34.048928 -111.093731     Arizona
# 4  36.778261 -119.417932  California

# %%
coronastats = pd.read_html('https://en.wikipedia.org/wiki/COVID-19_pandemic_in_the_United_States',match='U.S. state or territory')

# %%
covid19 = pd.DataFrame(coronastats[0])

covid19.head()
# Out:
#   [show all]vteCOVID-19 pandemic in the United States by state and territory  \
#                                                   U.S. state or territory[i]
#                                                                      55 / 56
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                                                      \
#                   Cases[ii]  Deaths Recov.[iii] Hosp.[iv]      Ref.
#         55 / 56.1 3,090,785 132,480           –         –       [v]
# 0         Alabama     51294    1086       22082      2961      [49]
# 1          Alaska      1184      17         560        78      [50]
# 2  American Samoa         0       0           –         –         –
# ...

# %%
covid19 = covid19.iloc[:, :-4]

# %%
covid19.head()
# Out:
#   [show all]vteCOVID-19 pandemic in the United States by state and territory  \
#                                                   U.S. state or territory[i]
#                                                                      55 / 56
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#
#                   Cases[ii]  Deaths Recov.[iii] Hosp.[iv]
#         55 / 56.1 3,090,785 132,480           –         –
# 0         Alabama     51294    1086       22082      2961
# 1          Alaska      1184      17         560        78
# 2  American Samoa         0       0           –         –
# 3         Arizona    116892    2082           –      5272
# 4        Arkansas     24253     292       17834      1604

# %%
covid19.columns = ['nana', 'state', 'total cases', 'deaths', 'recovered', 'hospitalized']

# %%
del covid19['nana']

# %%
del covid19['hospitalized']

# %%
covid19.head()
# Out:
#             state total cases deaths recovered
# 0         Alabama       51294   1086     22082
# 1          Alaska        1184     17       560
# 2  American Samoa           0      0         –
# 3         Arizona      116892   2082         –
# 4        Arkansas       24253    292     17834

# %%
ds = pd.merge(covid19, usa_cord, how ='inner', on ='state')
ds.head()
# Out:
#         state total cases deaths recovered   latitude   longitude
# 0     Alabama       51294   1086     22082  32.318231  -86.902298
# 1      Alaska        1184     17       560  63.588753 -154.493062
# 2     Arizona      116892   2082         –  34.048928 -111.093731
# 3    Arkansas       24253    292     17834  35.201050  -91.831833
# 4  California      296499   6711         –  36.778261 -119.417932

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 52 entries, 0 to 51
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   state        52 non-null     object
#  1   total cases  52 non-null     object
#  2   deaths       52 non-null     object
#  3   recovered    52 non-null     object
#  4   latitude     52 non-null     float64
#  5   longitude    52 non-null     float64
# dtypes: float64(2), object(4)
# memory usage: 2.8+ KB

# %%
import folium
from bokeh.io import output_file, show

# %%
america = folium.Map(location = [37.778261,-100.417932], zoom_start = 4)

# %%
for state,lat,long,total_cases,Death,Recov in zip(list(ds['state']),list(ds['latitude']),list(ds['longitude']),list(ds['total cases']),list(ds['deaths']),list(ds['recovered'])):
    
    folium.CircleMarker(location = [lat,long],
                       radius = 5,
                       color='red',
                       fill = True,
                       fill_color="red").add_to(america)
    
    folium.Marker(location = [lat,long],
                  # adding information that need to be displayed on popup
                  popup=folium.Popup(('<strong><b>State  : '+state+'</strong> <br>' +
                    '<strong><b>Total Cases : '+total_cases+'</striong><br>' +
                    '<strong><font color= red>Deaths : </font>'+Death+'</striong><br>' +
                    '<strong><font color=green>Recovered : </font>'+Recov+'</striong><br>'),max_width=200)).add_to(america)

# %%
america
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
america.save('plot_data.html')
